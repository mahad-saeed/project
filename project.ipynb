# %%
import pandas as pd
import os
import numpy as np
from mutagen.easyid3 import EasyID3
import librosa

# Define the file paths for the extracted CSV files
tracks_csv_path = '/home/syed/project/fma_metadata/metadata/tracks.csv'

# Load tracks data into a DataFrame
tracks_df = pd.read_csv(tracks_csv_path)

# Example function to extract MFCC and Spectral Centroid features from an audio file
def extract_features(audio_file):
    # Load audio file
    y, sr = librosa.load(audio_file)
    
    # Extract MFCC features
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    
    # Extract Spectral Centroid
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
    
    # Calculate mean values for MFCC and Spectral Centroid
    mean_mfcc = np.mean(mfcc, axis=1)
    mean_spectral_centroid = np.mean(spectral_centroid)
    
    
    return mfcc, spectral_centroid

# Function to extract titles from MP3 files in a folder
def extract_titles_from_mp3(folder):
    titles = {}
    
    # Traverse through each MP3 file in the folder
    for filename in os.listdir(folder):
        if filename.endswith('.mp3'):
            file_path = os.path.join(folder, filename)
            
            # Extract metadata using mutagen
            try:
                audio = EasyID3(file_path)
                title = audio['title'][0] if 'title' in audio else None
                titles[filename] = title
            except Exception as e:
                print(f"Error processing {filename}: {e}")
    
    return titles

# Example usage
folder = '/home/syed/project/fma_metadata/fma_large/000'
titles = extract_titles_from_mp3(folder)
print("Titles:", titles)

# Dictionary to store mapping between audio file titles and track IDs
audio_track_mapping = {}

# Iterate over the titles extracted from audio files
for audio_filename, title in titles.items():
    # Search for matching title in tracks_df
    match = tracks_df[tracks_df['title'] == title]
    # If a match is found, retrieve the track ID
    if not match.empty:
        # Extract the track_id from the matched row
        track_id = match['id'].iloc[0]  # Assuming there's only one match per title
        audio_track_mapping[audio_filename] = track_id
    else:
        print(f"No match found for title '{title}'")

print("Audio Track Mapping:", audio_track_mapping)


from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import re

# Define the file path for the extracted CSV file

# Load tracks data into a DataFrame
tracks_df = pd.read_csv(tracks_csv_path, header=[0, 1])

# Rename the 'id' column to ('track', 'id')
tracks_df.columns = [('track', 'id') if col[0] == 'id' else col for col in tracks_df.columns]

# Select relevant columns for preprocessing
selected_columns = [
    ('track', 'id'),  # Include the ('track', 'id') column separately
    ('album', 'title'), ('album', 'favorites'), ('album', 'listens'),
    ('artist', 'bio'), ('artist', 'location'), ('artist', 'associated_labels'),
    ('track', 'comments'), ('track', 'favorites'), ('track', 'listens'), ('track', 'genre_top')
]

# Extract the selected columns and create a new dataframe
selected_df = tracks_df[selected_columns]

# Preprocessing steps
# Fill missing values
selected_df.fillna({'artist_bio': '', 'artist_location': '', 'artist_labels': '',
                    'track_comments': 0, 'track_favorites': 0, 'track_listens': 0}, inplace=True)

# Text preprocessing for artist_bio
selected_df[('artist', 'bio')] = selected_df[('artist', 'bio')].str.lower()  # Lowercasing
selected_df[('artist', 'bio')] = selected_df[('artist', 'bio')].fillna('').apply(lambda x: re.sub(r'<[^>]+>', '', x))  # Remove HTML tags
selected_df[('artist', 'bio')] = selected_df[('artist', 'bio')].str.replace('[^\w\s]', '')  # Remove punctuation
selected_df[('artist', 'bio')] = selected_df[('artist', 'bio')].str.replace(r'\s+', ' ', regex=True).str.strip()  # Remove extra whitespaces
# Text preprocessing for artist_labels
selected_df[('artist', 'associated_labels')] = selected_df[('artist', 'associated_labels')].fillna('').apply(lambda x: re.sub(r'<[^>]+>', '', x))  # Remove HTML tags
selected_df[('artist', 'associated_labels')] = selected_df[('artist', 'associated_labels')].str.replace(r'\s*,\s*', ',')  # Remove spaces around commas
selected_df[('artist', 'associated_labels')] = selected_df[('artist', 'associated_labels')].str.split(',')  # Split the string by commas
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Initialize encoders and scaler
label_encoders = {}
scaler = StandardScaler()

# Separate numerical and categorical columns
numerical_columns = [('album', 'favorites'), ('album', 'listens'),
                     ('track', 'comments'), ('track', 'favorites'), ('track', 'listens')]
categorical_columns = [('album', 'title'), ('artist', 'bio'), ('artist', 'location'), ('artist', 'associated_labels'), ('track', 'genre_top')]

# Encoding and normalization for categorical columns
for col in categorical_columns:
    label_encoders[col] = LabelEncoder()
    selected_df[col] = label_encoders[col].fit_transform(selected_df[col].astype(str))
import numpy as np

# Replace non-numeric values with NaN
selected_df[numerical_columns] = selected_df[numerical_columns].apply(pd.to_numeric, errors='coerce')

# Drop rows with NaN values
selected_df.dropna(subset=numerical_columns, inplace=True)

# Normalization for numerical columns
selected_df[numerical_columns] = scaler.fit_transform(selected_df[numerical_columns])

# Print data types of numerical columns for the first few rows
print("Data types of numerical columns for the first few rows:")
print(selected_df[numerical_columns].head())

# Print data types of categorical columns for the first few rows
print("\nData types of categorical columns for the first few rows:")
print(selected_df[categorical_columns].head())
from pymongo import MongoClient
import os
import numpy as np

# Connect to MongoDB
mongo_uri = "mongodb://localhost:27017"
client = MongoClient(mongo_uri)

# Access or create a database
db = client['audio_features_database']

# Access or create a collection
collection = db['audio_features_collection']

# Iterate over the audio files and store their features in the collection
for audio_filename, track_id in audio_track_mapping.items():
    # Construct the full path to the audio file
    audio_file = os.path.join(folder, audio_filename)
    
    # Extract features from the audio file
    mfcc_features, spectral_centroid_feature = extract_features(audio_file)
    
    # Reshape the features for normalization
    mfcc_features_reshaped = mfcc_features.reshape(-1, 1)
    spectral_centroid_feature_reshaped = np.array([spectral_centroid_feature]).reshape(-1, 1)
    
    # Normalize the features
    normalized_mfcc_features = scaler.fit_transform(mfcc_features_reshaped).flatten().tolist()
    normalized_spectral_centroid_feature = scaler.fit_transform(spectral_centroid_feature_reshaped).flatten().tolist()
    
    # Fetch additional metadata from selected_df based on track_id
    metadata = selected_df[selected_df[('track', 'id')] == track_id].iloc[0]
    
    # Create a document to insert into the collection
    document = {
        'track_id': track_id,
        'audio_filename': audio_filename,
        'normalized_mfcc_features': normalized_mfcc_features,
        'normalized_spectral_centroid_feature': normalized_spectral_centroid_feature,
        'title': metadata[('album', 'title')],
        'favorites': metadata[('album', 'favorites')],
        'listens': metadata[('album', 'listens')],
        'genre': metadata[('track', 'genre_top')]
    }
    
    # Insert the document into the collection
    collection.insert_one(document)

print("Audio features along with metadata have been successfully stored in MongoDB.")
from pymongo import MongoClient
from annoy import AnnoyIndex
from pymongo import MongoClient
from annoy import AnnoyIndex

# Connect to MongoDB
try:
    client = MongoClient('mongodb://localhost:27017/')
    db = client['audio_features_database']
    collection = db['audio_features_collection']
except Exception as e:
    print("Error connecting to MongoDB:", e)
    exit()

# Retrieve data from MongoDB
try:
    data = collection.find({}, {'normalized_mfcc_features': 1, 'listens': 1, 'favorites': 1, 'genre': 1, 'normalized_spectral_centroid_feature': 1, 'title': 1, 'track_id': 1})
except Exception as e:
    print("Error retrieving data from MongoDB:", e)
    exit()

# Convert MongoDB cursor to a list of dictionaries
try:
    data_list = list(data)
except Exception as e:
    print("Error converting MongoDB cursor to list:", e)
    exit()

# Extract features and other relevant information
mfcc_features = [doc.get('normalized_mfcc_features', []) for doc in data_list]
spectral_centroid_features = [doc.get('normalized_spectral_centroid_feature', []) for doc in data_list]
titles = [doc.get('title', '') for doc in data_list]
track_ids = [doc.get('track_id', '') for doc in data_list]
genre = [doc.get('genre', '') for doc in data_list]

# Combine MFCC and spectral centroid features
combined_features = [np.hstack((mfcc, centroid)) for mfcc, centroid in zip(mfcc_features, spectral_centroid_features)]

# Build ANN index
num_features = len(combined_features[0]) if combined_features else 0
ann_index = AnnoyIndex(num_features, 'euclidean')
# Add items to the index
for i, feature_vector in enumerate(combined_features):
    # Check the length of the feature vector
    if len(feature_vector) == num_features:
        ann_index.add_item(i, feature_vector)
    else:

# Build the index
ann_index.build(n_trees=100)

# Function to recommend tracks based on a given track ID
def recommend_tracks(track_id, num_recommendations=5):
    try:
        track_index = track_ids.index(track_id)
    except ValueError:
        print(f"Track ID '{track_id}' not found.")
        return []

    neighbor_indices = ann_index.get_nns_by_item(track_index, num_recommendations)
    recommended_tracks = [(track_ids[idx], titles[idx]) for idx in neighbor_indices]

    return recommended_tracks

# Example usage
track_id_to_recommend_for = '1'
recommendations = recommend_tracks(track_id_to_recommend_for)
print("Recommended tracks:")
for track_id, title in recommendations:
    print(f"Track ID: {track_id}, Title: {title}")
from sklearn.metrics import average_precision_score
from sklearn.metrics import ndcg_score

# Ground truth data (replace this with your actual ground truth data)
ground_truth = {
    'user1': ['track3', 'track1'],
    'user2': ['track2', 'track1', 'track4'],
    # Add more users and their preferences here
}

# Function to evaluate the model using MAP and NDCG
def evaluate_model(recommendation_function):
    map_scores = []
    ndcg_scores = []
    
    for user, ground_truth_tracks in ground_truth.items():
        recommended_tracks = [track_id for track_id, _ in recommendation_function(user)]
        
        # Calculate Average Precision
        y_true = [1 if track in ground_truth_tracks else 0 for track in recommended_tracks]
        map_score = average_precision_score(y_true, range(len(y_true)))
        map_scores.append(map_score)
        
        # Calculate NDCG
        ground_truth_relevance = [1 if track in ground_truth_tracks else 0 for track in recommended_tracks]
        ndcg_score = ndcg_score([ground_truth_relevance], [ground_truth_relevance])
        ndcg_scores.append(ndcg_score)
    
    # Calculate average MAP and NDCG scores
    average_map = sum(map_scores) / len(map_scores)
    average_ndcg = sum(ndcg_scores) / len(ndcg_scores)
    
    print("Average MAP:", average_map)
    print("Average NDCG:", average_ndcg)

# Call the evaluate_model function with your recommendation function
evaluate_model(recommend_tracks)
# Out:
# /tmp/ipykernel_19122/2521206656.py:11: DtypeWarning: Columns (1,5,6,21,22,34,38,39,49,55,56,57,58,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   tracks_df = pd.read_csv(tracks_csv_path)
# Titles: {'000569.mp3': 'Shadow Law', '000483.mp3': 'Magnolias Milan', '000565.mp3': 'Sophia', '000495.mp3': 'Waterfall (Emerald City Coffee, Seattle)', '000554.mp3': 'Disturbed', '000561.mp3': 'Fairies', '000546.mp3': 'If You Have No One', '000515.mp3': "Let's Climb a Mossy Hill", '000468.mp3': 'Vast and Sad (KPSU)', '000501.mp3': 'Utmost House', '000576.mp3': 'Shot At the Post Office', '000490.mp3': 'Vast and Sad', '000469.mp3': 'Waverly', '000516.mp3': 'Kohoutek', '000513.mp3': 'Victoria 2', '000477.mp3': "Let's Climb a Mossy Hill (Kelly Haus)", '000481.mp3': 'Council Bluffs', '000514.mp3': 'Four Doors', '000538.mp3': 'Your Magic Motion', '000549.mp3': 'Venice, CA', '000560.mp3': 'Serious', '000493.mp3': 'In the Sky', '000476.mp3': 'Leftward Glance', '000498.mp3': 'Birdlike Movements', '000512.mp3': None, '000502.mp3': 'Vast and Sad (Showoff Gallery, Bellingham)', '000536.mp3': 'Riding On Your Fears', '000500.mp3': 'Longview, WA', '000470.mp3': 'Cloud Light', '000571.mp3': 'Medicine Chant', '000484.mp3': 'One Rose Among Many', '000496.mp3': 'Winged Ear', '000533.mp3': 'Mango Tree', '000562.mp3': 'Ex Lucky', '000567.mp3': "Liberty's Bell", '000472.mp3': 'Spirit Duplicator', '000473.mp3': 'Victoria 1', '000528.mp3': 'An Odd Number of Stairs', '000486.mp3': 'Avoid', '000489.mp3': 'Nevertheless', '000510.mp3': 'Sac City', '000526.mp3': 'Do Not Talk', '000508.mp3': '5 In 1', '000467.mp3': "Let's Climb a Mossy Hill", '000503.mp3': 'Carted Off', '000523.mp3': "Black Is the Color of My True Love's Mail", '000525.mp3': 'I Have Not Spoken All Day', '000471.mp3': 'Ephrata Cloister', '000480.mp3': 'Appear to Be (Kelly Haus)', '000482.mp3': 'Hall Blvd.', '000465.mp3': 'Thinking Of You', '000532.mp3': 'Big League', '000506.mp3': 'Moths!!!', '000485.mp3': 'Asterism (Kelly Haus)', '000557.mp3': "Waitin'", '000459.mp3': 'Machines and Muscles', '000537.mp3': "I Don't Need Water Sprinklers In The Desert", '000555.mp3': 'Shaking', '000497.mp3': 'Appear To Be', '000535.mp3': 'Angels Fear To Tread', '000461.mp3': 'Bessemer', '000550.mp3': 'Cello Duet No. 1', '000504.mp3': 'Cry', '000479.mp3': 'White Shoulders', '000524.mp3': "I Didn't Think the Oracle Was Talking to Me", '000511.mp3': 'Sharper and Clearer', '000507.mp3': 'Toasty Birds', '000529.mp3': 'For the Dishroom at Meridian Park Hospital', '000559.mp3': 'Takeaway', '000487.mp3': 'For Christie 7/4', '000522.mp3': 'End Over End', '000520.mp3': 'Invisible Tape', '000531.mp3': 'Night Air, Portland', '000521.mp3': 'A River Frozen In Place', '000509.mp3': "A Wren's Heart", '000491.mp3': 'For To Pour', '000534.mp3': 'I Can See You', '000527.mp3': 'For Jake Erdmann Et Al.', '000540.mp3': 'The Black Pirate', '000475.mp3': 'Buddy Alan In Reno', '000548.mp3': '1967- Mac Brother', '000563.mp3': 'Dumb Me Down', '000517.mp3': 'Narcotic Effect On Bees', '000545.mp3': 'Interpretations', '000492.mp3': "I Can't Hear the Birds Sing", '000541.mp3': 'So We Go Again', '000474.mp3': 'Your Leather Jacket (Kelly Haus)', '000466.mp3': 'Asterism', '000530.mp3': 'White Satin Bed', '000543.mp3': 'Sometimes It Works Just Right', '000464.mp3': 'The Way I Feel Today', '000542.mp3': 'Self Is Eternal (What Our World Will Be)', '000539.mp3': 'Whoever You Are', '000544.mp3': 'Sweet Words', '000478.mp3': 'Recessional'}
# No match found for title 'None'
# No match found for title 'Sharper and Clearer'
# Audio Track Mapping: {'000569.mp3': 569.0, '000483.mp3': 483.0, '000565.mp3': 565.0, '000495.mp3': 495.0, '000554.mp3': 554.0, '000561.mp3': 561.0, '000546.mp3': 546.0, '000515.mp3': 467.0, '000468.mp3': 468.0, '000501.mp3': 501.0, '000576.mp3': 576.0, '000490.mp3': 490.0, '000469.mp3': 469.0, '000516.mp3': 516.0, '000513.mp3': 513.0, '000477.mp3': 477.0, '000481.mp3': 481.0, '000514.mp3': 514.0, '000538.mp3': 538.0, '000549.mp3': 549.0, '000560.mp3': 560.0, '000493.mp3': 493.0, '000476.mp3': 476.0, '000498.mp3': 498.0, '000502.mp3': 502.0, '000536.mp3': 536.0, '000500.mp3': 500.0, '000470.mp3': 470.0, '000571.mp3': 571.0, '000484.mp3': 484.0, '000496.mp3': 496.0, '000533.mp3': 533.0, '000562.mp3': 562.0, '000567.mp3': 567.0, '000472.mp3': 472.0, '000473.mp3': 473.0, '000528.mp3': 528.0, '000486.mp3': 486.0, '000489.mp3': 489.0, '000510.mp3': 510.0, '000526.mp3': 526.0, '000508.mp3': 508.0, '000467.mp3': 467.0, '000503.mp3': 503.0, '000523.mp3': 523.0, '000525.mp3': 525.0, '000471.mp3': 471.0, '000480.mp3': 480.0, '000482.mp3': 482.0, '000465.mp3': 465.0, '000532.mp3': 532.0, '000506.mp3': 506.0, '000485.mp3': 485.0, '000557.mp3': 557.0, '000459.mp3': 459.0, '000537.mp3': 537.0, '000555.mp3': 555.0, '000497.mp3': 497.0, '000535.mp3': 535.0, '000461.mp3': 461.0, '000550.mp3': 550.0, '000504.mp3': 504.0, '000479.mp3': 479.0, '000524.mp3': 524.0, '000507.mp3': 507.0, '000529.mp3': 529.0, '000559.mp3': 559.0, '000487.mp3': 487.0, '000522.mp3': 522.0, '000520.mp3': 520.0, '000531.mp3': 531.0, '000521.mp3': 521.0, '000509.mp3': 509.0, '000491.mp3': 491.0, '000534.mp3': 534.0, '000527.mp3': 527.0, '000540.mp3': 540.0, '000475.mp3': 475.0, '000548.mp3': 548.0, '000563.mp3': 563.0, '000517.mp3': 517.0, '000545.mp3': 545.0, '000492.mp3': 492.0, '000541.mp3': 541.0, '000474.mp3': 474.0, '000466.mp3': 466.0, '000530.mp3': 530.0, '000543.mp3': 543.0, '000464.mp3': 464.0, '000542.mp3': 542.0, '000539.mp3': 539.0, '000544.mp3': 544.0, '000478.mp3': 478.0}
#
# --- Combined Detail---
# Track ID: 569.0, Audio File: 000569.mp3
# Normalized MFCC Features: [0.         0.2017335  0.24740362 ... 0.66531724 0.6599408  0.6555104 ]
# Normalized Spectral Centroid Feature: [0.         0.03253285 0.05752662 ... 0.43469754 0.44917398 0.50616689]
#
# --- Combined Detail---
# Track ID: 483.0, Audio File: 000483.mp3
# Normalized MFCC Features: [0.         0.3171775  0.42564633 ... 0.7060653  0.7056354  0.6981431 ]
# Normalized Spectral Centroid Feature: [0.08063682 0.1014962  0.10731764 ... 0.19896715 0.35712321 0.38806308]
#
# --- Combined Detail---
# Track ID: 565.0, Audio File: 000565.mp3
# Normalized MFCC Features: [0.         0.33251607 0.42124778 ... 0.5674311  0.5671529  0.56002074]
# Normalized Spectral Centroid Feature: [0.1550759  0.12338068 0.12837561 ... 0.16960938 0.18581073 0.19815797]
#
# --- Combined Detail---
# Track ID: 495.0, Audio File: 000495.mp3
# Normalized MFCC Features: [0.09737396 0.47319514 0.56508255 ... 0.4321009  0.43958586 0.44530243]
# Normalized Spectral Centroid Feature: [0.5458509  0.58435008 0.67474645 ... 0.07892819 0.06397833 0.05928564]
#
# --- Combined Detail---
# Track ID: 554.0, Audio File: 000554.mp3
# Normalized MFCC Features: [0.         0.23907965 0.28737783 ... 0.6752663  0.66978645 0.6714732 ]
# Normalized Spectral Centroid Feature: [0.0739254  0.08448533 0.09190781 ... 0.12797161 0.11777274 0.14651444]
#
# --- Combined Detail---
# Track ID: 561.0, Audio File: 000561.mp3
# Normalized MFCC Features: [0.01916391 0.27186972 0.34591842 ... 0.6549544  0.6610401  0.65694743]
# Normalized Spectral Centroid Feature: [0.10800759 0.09978026 0.09929688 ... 0.13878809 0.21743702 0.2580984 ]
#
# --- Combined Detail---
# Track ID: 546.0, Audio File: 000546.mp3
# Normalized MFCC Features: [0.         0.18807879 0.23897186 ... 0.6536726  0.653619   0.6512878 ]
# Normalized Spectral Centroid Feature: [0.0822618  0.09319245 0.10735376 ... 0.06950299 0.05472863 0.07163833]
#
# --- Combined Detail---
# Track ID: 467.0, Audio File: 000515.mp3
# Normalized MFCC Features: [0.07858396 0.44827527 0.5608929  ... 0.65193087 0.6463961  0.64711654]
# Normalized Spectral Centroid Feature: [0.30606894 0.39996978 0.44185777 ... 0.41915811 0.44143423 0.5551252 ]
#
# --- Combined Detail---
# Track ID: 468.0, Audio File: 000468.mp3
# Normalized MFCC Features: [0.28136137 0.58253133 0.67949396 ... 0.6481079  0.6415522  0.6534406 ]
# Normalized Spectral Centroid Feature: [0.38238215 0.37308257 0.36420929 ... 0.41821312 0.41675796 0.45075518]
#
# --- Combined Detail---
# Track ID: 501.0, Audio File: 000501.mp3
# Normalized MFCC Features: [0.         0.4050944  0.5089846  ... 0.6182278  0.61027575 0.60809374]
# Normalized Spectral Centroid Feature: [0.67074658 0.60080691 0.5652267  ... 0.46933939 0.41621921 0.38958343]
#
# --- Combined Detail---
# Track ID: 576.0, Audio File: 000576.mp3
# Normalized MFCC Features: [0.         0.34648412 0.43005532 ... 0.6460587  0.63784045 0.64296895]
# Normalized Spectral Centroid Feature: [0.         0.05052361 0.11912038 ... 0.63736347 0.63508104 0.59458893]
#
# --- Combined Detail---
# Track ID: 490.0, Audio File: 000490.mp3
# Normalized MFCC Features: [0.         0.34386092 0.4340094  ... 0.6705906  0.6786394  0.68562853]
# Normalized Spectral Centroid Feature: [0.10609683 0.09698364 0.09815079 ... 0.34380181 0.2792741  0.29891533]
#
# --- Combined Detail---
# Track ID: 469.0, Audio File: 000469.mp3
# Normalized MFCC Features: [0.         0.38241076 0.48005265 ... 0.6472143  0.638895   0.6367373 ]
# Normalized Spectral Centroid Feature: [0.31242369 0.33884384 0.42690808 ... 0.51791991 0.61819904 0.61694572]
#
# --- Combined Detail---
# Track ID: 516.0, Audio File: 000516.mp3
# Normalized MFCC Features: [0.06116152 0.29300827 0.48458898 ... 0.7168402  0.7102433  0.7159075 ]
# Normalized Spectral Centroid Feature: [0.03837363 0.09000568 0.18115752 ... 0.04633434 0.03473382 0.06495433]
#
# --- Combined Detail---
# Track ID: 513.0, Audio File: 000513.mp3
# Normalized MFCC Features: [0.         0.42218995 0.53186977 ... 0.6618019  0.674863   0.68316907]
# Normalized Spectral Centroid Feature: [0.27273374 0.34237495 0.38726975 ... 0.27314638 0.29437293 0.28663291]
#
# --- Combined Detail---
# Track ID: 477.0, Audio File: 000477.mp3
# Normalized MFCC Features: [0.         0.39371952 0.514003   ... 0.56419545 0.5498892  0.5455198 ]
# Normalized Spectral Centroid Feature: [0.06972626 0.11587757 0.16241332 ... 0.36367253 0.26162925 0.08976694]
#
# --- Combined Detail---
# Track ID: 481.0, Audio File: 000481.mp3
# Normalized MFCC Features: [0.         0.12441075 0.32346484 ... 0.7057094  0.7023659  0.69948685]
# Normalized Spectral Centroid Feature: [0.62939312 0.50880503 0.58310792 ... 0.0369889  0.04228783 0.09803982]
#
# --- Combined Detail---
# Track ID: 514.0, Audio File: 000514.mp3
# Normalized MFCC Features: [0.         0.1343466  0.30553493 ... 0.75785583 0.75538    0.7513791 ]
# Normalized Spectral Centroid Feature: [0.43429609 0.36005799 0.31563632 ... 0.14994489 0.17776907 0.31243868]
#
# --- Combined Detail---
# Track ID: 538.0, Audio File: 000538.mp3
# Normalized MFCC Features: [0.         0.26736823 0.33473933 ... 0.6385092  0.6426666  0.6463259 ]
# Normalized Spectral Centroid Feature: [0.79817391 0.78694355 0.74697663 ... 0.08722487 0.13382236 0.363151  ]
#
# --- Combined Detail---
# Track ID: 549.0, Audio File: 000549.mp3
# Normalized MFCC Features: [0.         0.18094528 0.24763879 ... 0.7173616  0.71386296 0.71400833]
# Normalized Spectral Centroid Feature: [0.00493448 0.02335849 0.05576692 ... 0.24228374 0.23417552 0.20702264]
#
# --- Combined Detail---
# Track ID: 560.0, Audio File: 000560.mp3
# Normalized MFCC Features: [0.         0.14959568 0.17302111 ... 0.62811154 0.62162876 0.61857855]
# Normalized Spectral Centroid Feature: [0.10035238 0.10378427 0.09621221 ... 0.30067225 0.25033978 0.2288992 ]
#
# --- Combined Detail---
# Track ID: 493.0, Audio File: 000493.mp3
# Normalized MFCC Features: [0.         0.27436715 0.34898037 ... 0.6614594  0.652123   0.6527219 ]
# Normalized Spectral Centroid Feature: [0.11814889 0.14987111 0.19087241 ... 0.16752196 0.14854349 0.16497888]
#
# --- Combined Detail---
# Track ID: 476.0, Audio File: 000476.mp3
# Normalized MFCC Features: [0.06960231 0.22002468 0.25028712 ... 0.6590949  0.6619926  0.6679703 ]
# Normalized Spectral Centroid Feature: [0.2152049  0.19699722 0.16066918 ... 0.24746377 0.21025942 0.17576138]
#
# --- Combined Detail---
# Track ID: 498.0, Audio File: 000498.mp3
# Normalized MFCC Features: [0.         0.21644956 0.26279968 ... 0.76052266 0.74901855 0.7575617 ]
# Normalized Spectral Centroid Feature: [0.55704212 0.60347113 0.61705286 ... 0.05007179 0.06639382 0.11187392]
#
# --- Combined Detail---
# Track ID: 502.0, Audio File: 000502.mp3
# Normalized MFCC Features: [0.02388388 0.42106622 0.49138328 ... 0.592988   0.59921104 0.60717225]
# Normalized Spectral Centroid Feature: [0.2748934  0.2501619  0.23705044 ... 0.23001989 0.24216409 0.24741573]
#
# --- Combined Detail---
# Track ID: 536.0, Audio File: 000536.mp3
# Normalized MFCC Features: [0.         0.19453555 0.26106837 ... 0.6970858  0.7009752  0.7020669 ]
# Normalized Spectral Centroid Feature: [0.11865952 0.10992298 0.11833795 ... 0.0864589  0.06451139 0.11266098]
#
# --- Combined Detail---
# Track ID: 500.0, Audio File: 000500.mp3
# Normalized MFCC Features: [0.39806804 0.5861589  0.6134855  ... 0.68109906 0.6799704  0.68059415]
# Normalized Spectral Centroid Feature: [0.5780623  0.55282832 0.45368588 ... 0.47914734 0.44713183 0.36521192]
#
# --- Combined Detail---
# Track ID: 470.0, Audio File: 000470.mp3
# Normalized MFCC Features: [0.11379337 0.32597843 0.35992426 ... 0.63542265 0.64149356 0.64124274]
# Normalized Spectral Centroid Feature: [0.42206859 0.42559297 0.41710166 ... 0.29510807 0.34642543 0.30793217]
#
# --- Combined Detail---
# Track ID: 571.0, Audio File: 000571.mp3
# Normalized MFCC Features: [0.24570534 0.46462572 0.5129075  ... 0.68965214 0.684428   0.6835708 ]
# Normalized Spectral Centroid Feature: [0.09535848 0.11218531 0.13972623 ... 0.0717801  0.0646534  0.0708535 ]
#
# --- Combined Detail---
# Track ID: 484.0, Audio File: 000484.mp3
# Normalized MFCC Features: [0.         0.34346643 0.43770158 ... 0.5741251  0.5762471  0.5761762 ]
# Normalized Spectral Centroid Feature: [0.21395451 0.24333844 0.27160759 ... 0.34965963 0.34739841 0.40186812]
#
# --- Combined Detail---
# Track ID: 496.0, Audio File: 000496.mp3
# Normalized MFCC Features: [0.         0.3006461  0.37872368 ... 0.534913   0.53370714 0.53291655]
# Normalized Spectral Centroid Feature: [0.16922604 0.19481571 0.23833993 ... 0.24020357 0.19169304 0.33147312]
#
# --- Combined Detail---
# Track ID: 533.0, Audio File: 000533.mp3
# Normalized MFCC Features: [0.32523152 0.531849   0.57837534 ... 0.7454711  0.7453772  0.747408  ]
# Normalized Spectral Centroid Feature: [0.21757675 0.22663093 0.23850645 ... 0.29027732 0.43475103 0.49737087]
#
# --- Combined Detail---
# Track ID: 562.0, Audio File: 000562.mp3
# Normalized MFCC Features: [0.         0.1277734  0.19858211 ... 0.691944   0.70022535 0.70234954]
# Normalized Spectral Centroid Feature: [0.01381592 0.05269088 0.13639004 ... 0.47927963 1.         0.92565704]
#
# --- Combined Detail---
# Track ID: 567.0, Audio File: 000567.mp3
# Normalized MFCC Features: [0.20055908 0.40906313 0.45533735 ... 0.7212415  0.72156227 0.72232836]
# Normalized Spectral Centroid Feature: [0.18383115 0.1746074  0.18911172 ... 0.13919476 0.10310049 0.14414184]
#
# --- Combined Detail---
# Track ID: 472.0, Audio File: 000472.mp3
# Normalized MFCC Features: [0.         0.36961412 0.47587836 ... 0.6401792  0.63234794 0.62798524]
# Normalized Spectral Centroid Feature: [0.07415289 0.08979643 0.13188308 ... 0.1063643  0.19459358 0.20252526]
#
# --- Combined Detail---
# Track ID: 473.0, Audio File: 000473.mp3
# Normalized MFCC Features: [0.         0.3088948  0.5632829  ... 0.72528356 0.73762834 0.75041366]
# Normalized Spectral Centroid Feature: [0.32808808 0.2427811  0.3245723  ... 0.47529063 0.58779876 0.50077426]
#
# --- Combined Detail---
# Track ID: 528.0, Audio File: 000528.mp3
# Normalized MFCC Features: [0.         0.29734403 0.37778282 ... 0.5877183  0.5849447  0.58637285]
# Normalized Spectral Centroid Feature: [0.63351691 0.59029149 0.56178275 ... 0.21447242 0.4250389  0.48407261]
#
# --- Combined Detail---
# Track ID: 486.0, Audio File: 000486.mp3
# Normalized MFCC Features: [0.         0.41989055 0.68633616 ... 0.801765   0.7946017  0.8057768 ]
# Normalized Spectral Centroid Feature: [0.19130038 0.26581536 0.33567059 ... 0.27864172 0.26410873 0.18756671]
#
# --- Combined Detail---
# Track ID: 489.0, Audio File: 000489.mp3
# Normalized MFCC Features: [0.17250109 0.46847534 0.5633128  ... 0.7245786  0.71465725 0.70962024]
# Normalized Spectral Centroid Feature: [0.53827332 0.60211751 0.67009747 ... 0.60107707 0.6680691  0.62789894]
#
# --- Combined Detail---
# Track ID: 510.0, Audio File: 000510.mp3
# Normalized MFCC Features: [0.13140249 0.33675548 0.3827565  ... 0.7871107  0.7976672  0.7770996 ]
# Normalized Spectral Centroid Feature: [0.16369094 0.16974841 0.1787813  ... 0.27699942 0.28340578 0.25766432]
#
# --- Combined Detail---
# Track ID: 526.0, Audio File: 000526.mp3
# Normalized MFCC Features: [0.127558   0.37356538 0.43303153 ... 0.63417125 0.64228487 0.6472646 ]
# Normalized Spectral Centroid Feature: [0.200507   0.2035083  0.22478338 ... 0.25531794 0.26424489 0.26207405]
#
# --- Combined Detail---
# Track ID: 508.0, Audio File: 000508.mp3
# Normalized MFCC Features: [0.         0.14933228 0.28590482 ... 0.7249589  0.7188705  0.71868193]
# Normalized Spectral Centroid Feature: [0.21991921 0.01249704 0.01438742 ... 0.07410801 0.09342071 0.13677629]
#
# --- Combined Detail---
# Track ID: 467.0, Audio File: 000467.mp3
# Normalized MFCC Features: [0.         0.47673666 0.6307237  ... 0.6627962  0.66963625 0.67208457]
# Normalized Spectral Centroid Feature: [0.25370054 0.23399759 0.22729144 ... 0.27400312 0.20211508 0.20365442]
#
# --- Combined Detail---
# Track ID: 503.0, Audio File: 000503.mp3
# Normalized MFCC Features: [0.         0.19019055 0.25998604 ... 0.7003291  0.69952285 0.70061725]
# Normalized Spectral Centroid Feature: [0.03879081 0.0638654  0.08294654 ... 0.8317673  0.83121792 0.64488796]
#
# --- Combined Detail---
# Track ID: 523.0, Audio File: 000523.mp3
# Normalized MFCC Features: [0.         0.34027773 0.42792636 ... 0.66669476 0.6613337  0.65858096]
# Normalized Spectral Centroid Feature: [0.44719938 0.47468475 0.40241439 ... 0.33905389 0.18818663 0.08275728]
#
# --- Combined Detail---
# Track ID: 525.0, Audio File: 000525.mp3
# Normalized MFCC Features: [0.         0.28823534 0.3629787  ... 0.65208906 0.6569669  0.67477024]
# Normalized Spectral Centroid Feature: [0.28772817 0.30789102 0.30179115 ... 0.54530472 0.55749647 0.58505375]
#
# --- Combined Detail---
# Track ID: 471.0, Audio File: 000471.mp3
# Normalized MFCC Features: [0.07314217 0.3720988  0.43601084 ... 0.6367241  0.63439935 0.641025  ]
# Normalized Spectral Centroid Feature: [0.29548527 0.29967349 0.33459111 ... 0.25703669 0.26088665 0.27314898]
#
# --- Combined Detail---
# Track ID: 480.0, Audio File: 000480.mp3
# Normalized MFCC Features: [0.         0.5537581  0.70989686 ... 0.54336864 0.53837925 0.5420371 ]
# Normalized Spectral Centroid Feature: [0.37358548 0.50836091 0.66318173 ... 0.7734958  0.69659776 0.51286431]
#
# --- Combined Detail---
# Track ID: 482.0, Audio File: 000482.mp3
# Normalized MFCC Features: [0.         0.23776609 0.29786685 ... 0.5884425  0.58327264 0.5931506 ]
# Normalized Spectral Centroid Feature: [0.28381514 0.23811013 0.25837536 ... 0.24999666 0.23717051 0.24086957]
#
# --- Combined Detail---
# Track ID: 465.0, Audio File: 000465.mp3
# Normalized MFCC Features: [0.         0.33006302 0.39419228 ... 0.6495986  0.6507133  0.6529452 ]
# Normalized Spectral Centroid Feature: [0.61923637 0.51580653 0.38728087 ... 0.38095289 0.45437877 0.55745509]
#
# --- Combined Detail---
# Track ID: 532.0, Audio File: 000532.mp3
# Normalized MFCC Features: [0.18589598 0.5410874  0.6010908  ... 0.6104749  0.62448853 0.6307713 ]
# Normalized Spectral Centroid Feature: [0.40984947 0.28798445 0.25509681 ... 0.09840606 0.22242624 0.3424006 ]
#
# --- Combined Detail---
# Track ID: 506.0, Audio File: 000506.mp3
# Normalized MFCC Features: [0.         0.3788234  0.48436302 ... 0.6276299  0.62289655 0.6211028 ]
# Normalized Spectral Centroid Feature: [0.6815042  0.69014364 0.65323446 ... 0.21251205 0.15308855 0.23950046]
#
# --- Combined Detail---
# Track ID: 485.0, Audio File: 000485.mp3
# Normalized MFCC Features: [0.         0.5493951  0.6967908  ... 0.40845162 0.43158227 0.43888038]
# Normalized Spectral Centroid Feature: [0.90074057 0.88723174 0.94001143 ... 0.87843969 0.85749267 0.87205466]
#
# --- Combined Detail---
# Track ID: 557.0, Audio File: 000557.mp3
# Normalized MFCC Features: [0.02227163 0.26386362 0.33358568 ... 0.5966349  0.6079606  0.6152101 ]
# Normalized Spectral Centroid Feature: [0.20212538 0.18268575 0.1643461  ... 0.31852891 0.30286519 0.27644942]
#
# --- Combined Detail---
# Track ID: 459.0, Audio File: 000459.mp3
# Normalized MFCC Features: [0.         0.40294194 0.50082755 ... 0.55295235 0.5535038  0.55918545]
# Normalized Spectral Centroid Feature: [0.         0.15026304 0.23378563 ... 0.89743074 0.8854058  0.80965959]
#
# --- Combined Detail---
# Track ID: 537.0, Audio File: 000537.mp3
# Normalized MFCC Features: [0.         0.1761747  0.23317051 ... 0.69739497 0.69597584 0.6991734 ]
# Normalized Spectral Centroid Feature: [0.09232581 0.12853524 0.14746122 ... 0.171107   0.17921711 0.20234818]
#
# --- Combined Detail---
# Track ID: 555.0, Audio File: 000555.mp3
# Normalized MFCC Features: [0.         0.28453386 0.35311306 ... 0.64959747 0.6632662  0.6538837 ]
# Normalized Spectral Centroid Feature: [0.14810978 0.15365905 0.16532471 ... 0.26950038 0.20267708 0.12319365]
#
# --- Combined Detail---
# Track ID: 497.0, Audio File: 000497.mp3
# Normalized MFCC Features: [0.         0.5339469  0.7889776  ... 0.79006505 0.7922604  0.80068934]
# Normalized Spectral Centroid Feature: [0.35220953 0.42329101 0.41952297 ... 0.64626226 0.43754065 0.30102333]
#
# --- Combined Detail---
# Track ID: 535.0, Audio File: 000535.mp3
# Normalized MFCC Features: [0.         0.15719092 0.21496874 ... 0.68953645 0.69765806 0.70023715]
# Normalized Spectral Centroid Feature: [0.13870033 0.11564042 0.13072892 ... 0.17336914 0.13475407 0.13075142]
#
# --- Combined Detail---
# Track ID: 461.0, Audio File: 000461.mp3
# Normalized MFCC Features: [0.         0.2714508  0.32815647 ... 0.70418143 0.70460933 0.70653415]
# Normalized Spectral Centroid Feature: [0.08132694 0.08846774 0.13692488 ... 0.29347633 0.24148687 0.19564678]
#
# --- Combined Detail---
# Track ID: 550.0, Audio File: 000550.mp3
# Normalized MFCC Features: [0.01877648 0.05666387 0.04474735 ... 0.6419361  0.64312124 0.6418382 ]
# Normalized Spectral Centroid Feature: [0.05459936 0.02918044 0.00641663 ... 0.94005617 0.91168872 0.87786265]
#
# --- Combined Detail---
# Track ID: 504.0, Audio File: 000504.mp3
# Normalized MFCC Features: [0.         0.21151727 0.27729332 ... 0.53002524 0.53176093 0.53008306]
# Normalized Spectral Centroid Feature: [0.276302   0.2550046  0.2950332  ... 0.36099065 0.36142396 0.58726473]
#
# --- Combined Detail---
# Track ID: 479.0, Audio File: 000479.mp3
# Normalized MFCC Features: [0.         0.25292516 0.4738654  ... 0.7970069  0.7986519  0.7945952 ]
# Normalized Spectral Centroid Feature: [0.         0.19598486 0.17650926 ... 0.48862857 0.45718352 0.3916442 ]
#
# --- Combined Detail---
# Track ID: 524.0, Audio File: 000524.mp3
# Normalized MFCC Features: [0.         0.31597927 0.41417074 ... 0.60091823 0.6044998  0.59629184]
# Normalized Spectral Centroid Feature: [0.         0.01872285 0.07781846 ... 0.22933402 0.1606887  0.1549422 ]
#
# --- Combined Detail---
# Track ID: 507.0, Audio File: 000507.mp3
# Normalized MFCC Features: [0.         0.229855   0.2815742  ... 0.62707835 0.6349319  0.64394826]
# Normalized Spectral Centroid Feature: [0.03968025 0.07381708 0.11641458 ... 0.21607243 0.22574683 0.25339689]
#
# --- Combined Detail---
# Track ID: 529.0, Audio File: 000529.mp3
# Normalized MFCC Features: [0.         0.34054747 0.4389087  ... 0.5912794  0.58502096 0.5870122 ]
# Normalized Spectral Centroid Feature: [0.14841741 0.1469488  0.23113115 ... 0.12180264 0.11488635 0.19946168]
#
# --- Combined Detail---
# Track ID: 559.0, Audio File: 000559.mp3
# Normalized MFCC Features: [0.21817058 0.48735029 0.5642275  ... 0.5907876  0.5938349  0.60494494]
# Normalized Spectral Centroid Feature: [0.46959494 0.424257   0.40141548 ... 0.6394801  0.56994617 0.53930532]
#
# --- Combined Detail---
# Track ID: 487.0, Audio File: 000487.mp3
# Normalized MFCC Features: [0.         0.26282382 0.336862   ... 0.679634   0.67779654 0.67716324]
# Normalized Spectral Centroid Feature: [0.15986854 0.15030025 0.17648787 ... 0.19413491 0.17360178 0.1390576 ]
#
# --- Combined Detail---
# Track ID: 522.0, Audio File: 000522.mp3
# Normalized MFCC Features: [0.         0.3966465  0.48673385 ... 0.5056701  0.51164234 0.5324077 ]
# Normalized Spectral Centroid Feature: [0.27982418 0.3466939  0.35631241 ... 0.40416686 0.40701843 0.39351538]
#
# --- Combined Detail---
# Track ID: 520.0, Audio File: 000520.mp3
# Normalized MFCC Features: [0.         0.26987568 0.31065395 ... 0.6241195  0.62575924 0.62026185]
# Normalized Spectral Centroid Feature: [0.3765962  0.44817207 0.49386779 ... 0.33818794 0.31260634 0.31582952]
#
# --- Combined Detail---
# Track ID: 531.0, Audio File: 000531.mp3
# Normalized MFCC Features: [0.         0.29280052 0.40906173 ... 0.70100033 0.70135266 0.7038114 ]
# Normalized Spectral Centroid Feature: [0.38658663 0.34845064 0.19992483 ... 0.16874241 0.1672618  0.16289387]
#
# --- Combined Detail---
# Track ID: 521.0, Audio File: 000521.mp3
# Normalized MFCC Features: [0.         0.33390746 0.4391985  ... 0.65945774 0.6682278  0.66832775]
# Normalized Spectral Centroid Feature: [0.0989221  0.06718096 0.20068873 ... 0.4763005  0.37742918 0.37173811]
#
# --- Combined Detail---
# Track ID: 509.0, Audio File: 000509.mp3
# Normalized MFCC Features: [0.         0.10394078 0.14844573 ... 0.71873564 0.716974   0.71621364]
# Normalized Spectral Centroid Feature: [0.17525275 0.26105287 0.32662439 ... 0.4328651  0.5326727  0.49899391]
#
# --- Combined Detail---
# Track ID: 491.0, Audio File: 000491.mp3
# Normalized MFCC Features: [0.         0.2655555  0.49733815 ... 0.74763185 0.76345867 0.7695487 ]
# Normalized Spectral Centroid Feature: [0.38518112 0.39508155 0.3015002  ... 0.2723337  0.34289459 0.42180842]
#
# --- Combined Detail---
# Track ID: 534.0, Audio File: 000534.mp3
# Normalized MFCC Features: [0.         0.17747933 0.36636546 ... 0.6659871  0.6723563  0.6834131 ]
# Normalized Spectral Centroid Feature: [0.11914045 0.14171315 0.35276501 ... 0.10680148 0.12972857 0.14956665]
#
# --- Combined Detail---
# Track ID: 527.0, Audio File: 000527.mp3
# Normalized MFCC Features: [0.         0.3377424  0.40520537 ... 0.59981894 0.5856577  0.5605604 ]
# Normalized Spectral Centroid Feature: [0.48920297 0.54263697 0.56700131 ... 0.50382443 0.48293222 0.53524789]
#
# --- Combined Detail---
# Track ID: 540.0, Audio File: 000540.mp3
# Normalized MFCC Features: [0.1321016  0.37982517 0.44028565 ... 0.66286874 0.66390085 0.66375905]
# Normalized Spectral Centroid Feature: [0.08000656 0.1404631  0.19933339 ... 0.25664926 0.2554562  0.20398682]
#
# --- Combined Detail---
# Track ID: 475.0, Audio File: 000475.mp3
# Normalized MFCC Features: [0.         0.4101106  0.49108064 ... 0.5672609  0.5747149  0.5896042 ]
# Normalized Spectral Centroid Feature: [0.50328906 0.53738992 0.60774637 ... 0.81076377 0.89973217 0.89975012]
#
# --- Combined Detail---
# Track ID: 548.0, Audio File: 000548.mp3
# Normalized MFCC Features: [0.         0.14871997 0.20560521 ... 0.7145064  0.7172107  0.7206631 ]
# Normalized Spectral Centroid Feature: [0.1759165  0.11155031 0.11785999 ... 0.16375784 0.1410791  0.16685266]
#
# --- Combined Detail---
# Track ID: 563.0, Audio File: 000563.mp3
# Normalized MFCC Features: [0.         0.16209662 0.22295505 ... 0.6986176  0.70224965 0.705427  ]
# Normalized Spectral Centroid Feature: [0.01008874 0.04661103 0.07323664 ... 0.57361552 0.57094695 0.57085538]
#
# --- Combined Detail---
# Track ID: 517.0, Audio File: 000517.mp3
# Normalized MFCC Features: [0.         0.41730696 0.52931213 ... 0.4590352  0.4518954  0.4473707 ]
# Normalized Spectral Centroid Feature: [0.10036104 0.13181072 0.20655404 ... 0.48234693 0.4634108  0.47838554]
#
# --- Combined Detail---
# Track ID: 545.0, Audio File: 000545.mp3
# Normalized MFCC Features: [0.         0.17493325 0.24382865 ... 0.70997196 0.708468   0.71179587]
# Normalized Spectral Centroid Feature: [0.31014223 0.31933274 0.36857361 ... 0.18593993 0.17932235 0.11799343]
#
# --- Combined Detail---
# Track ID: 492.0, Audio File: 000492.mp3
# Normalized MFCC Features: [0.         0.39346075 0.49898577 ... 0.5888844  0.60862774 0.6116641 ]
# Normalized Spectral Centroid Feature: [0.47876484 0.50426625 0.50950614 ... 0.44786484 0.40068561 0.33787548]
#
# --- Combined Detail---
# Track ID: 541.0, Audio File: 000541.mp3
# Normalized MFCC Features: [0.         0.13570344 0.27668983 ... 0.7335693  0.7424746  0.74647695]
# Normalized Spectral Centroid Feature: [0.07126048 0.         0.02593893 ... 0.21462263 0.28882277 0.3538998 ]
#
# --- Combined Detail---
# Track ID: 474.0, Audio File: 000474.mp3
# Normalized MFCC Features: [0.         0.43621242 0.53350633 ... 0.5718171  0.5686129  0.56709987]
# Normalized Spectral Centroid Feature: [0.34098487 0.44760325 0.51579855 ... 0.53035999 0.5219143  0.42282443]
#
# --- Combined Detail---
# Track ID: 466.0, Audio File: 000466.mp3
# Normalized MFCC Features: [0.         0.18834805 0.2627316  ... 0.7054859  0.69966614 0.69651884]
# Normalized Spectral Centroid Feature: [0.05562619 0.07772127 0.13244493 ... 0.04907838 0.04720988 0.06739012]
#
# --- Combined Detail---
# Track ID: 530.0, Audio File: 000530.mp3
# Normalized MFCC Features: [0.         0.35820046 0.4613697  ... 0.5831258  0.5835184  0.5781844 ]
# Normalized Spectral Centroid Feature: [0.30049859 0.30381626 0.3893941  ... 0.27796709 0.29318457 0.268087  ]
#
# --- Combined Detail---
# Track ID: 543.0, Audio File: 000543.mp3
# Normalized MFCC Features: [0.         0.23981681 0.3160443  ... 0.7078394  0.71089494 0.71267074]
# Normalized Spectral Centroid Feature: [0.61940659 0.58446227 0.63882908 ... 0.57035484 0.53523505 0.52720794]
#
# --- Combined Detail---
# Track ID: 464.0, Audio File: 000464.mp3
# Normalized MFCC Features: [0.13839406 0.41498575 0.47294828 ... 0.694872   0.70684874 0.7215299 ]
# Normalized Spectral Centroid Feature: [0.23316169 0.2108191  0.20717693 ... 0.55263793 0.64435904 0.57169248]
#
# --- Combined Detail---
# Track ID: 542.0, Audio File: 000542.mp3
# Normalized MFCC Features: [0.         0.302298   0.4202308  ... 0.6444926  0.65072715 0.64507073]
# Normalized Spectral Centroid Feature: [0.21741771 0.26261471 0.34976397 ... 0.1437226  0.23925912 0.32424808]
#
# --- Combined Detail---
# Track ID: 539.0, Audio File: 000539.mp3
# Normalized MFCC Features: [0.         0.16792601 0.23218706 ... 0.71946263 0.7215393  0.7204541 ]
# Normalized Spectral Centroid Feature: [0.09255432 0.07274174 0.09836283 ... 0.84794782 0.56098703 0.28684562]
#
# --- Combined Detail---
# Track ID: 544.0, Audio File: 000544.mp3
# Normalized MFCC Features: [0.         0.07913351 0.22143763 ... 0.76009375 0.76110995 0.76008767]
# Normalized Spectral Centroid Feature: [0.14433433 0.14932035 0.15954886 ... 0.18468186 0.20780286 0.18565592]
#
# --- Combined Detail---
# Track ID: 478.0, Audio File: 000478.mp3
# Normalized MFCC Features: [0.37555638 0.6003019  0.648634   ... 0.6981565  0.7022383  0.70659024]
# Normalized Spectral Centroid Feature: [0.22109373 0.25840641 0.27961842 ... 0.30336656 0.26516296 0.22148416]

# %%
from pymongo import MongoClient

# Connect to MongoDB (assuming it's running locally on the default port)
client = MongoClient('localhost', 27017)

# Access or create a database
db = client['audio_features_database']

# Access or create a collection
collection = db['audio_features_collection']

# Iterate over the audio files and store their features in the collection
for audio_filename, track_id in audio_track_mapping.items():
    # Construct the full path to the audio file
    audio_file = os.path.join(folder, audio_filename)
    
    # Extract features from the audio file
    mfcc_features, spectral_centroid_feature = extract_features(audio_file)
    
    # Reshape the features for normalization
    mfcc_features_reshaped = mfcc_features.reshape(-1, 1)
    spectral_centroid_feature_reshaped = np.array([spectral_centroid_feature]).reshape(-1, 1)
    
    # Normalize the features
    normalized_mfcc_features = scaler.fit_transform(mfcc_features_reshaped).flatten().tolist()
    normalized_spectral_centroid_feature = scaler.fit_transform(spectral_centroid_feature_reshaped).flatten().tolist()
    
    # Create a document to insert into the collection
    document = {
        'track_id': track_id,
        'audio_filename': audio_filename,
        'normalized_mfcc_features': normalized_mfcc_features,
        'normalized_spectral_centroid_feature': normalized_spectral_centroid_feature
    }
    
    # Insert the document into the collection
    collection.insert_one(document)

print("Audio features have been successfully stored in MongoDB.")
# Out:
# Audio features have been successfully stored in MongoDB.

# %%
# Find all documents
result_all = collection.find()
print("Found all documents:")
for document in result_all:
    print(document)
